# %%
import mysql.connector

# %%
cnx = mysql.connector.connect(user='root', password='',
                              host='127.0.0.1',
                              database='project')

# %%
cursor = cnx.cursor()

# %%
query = "select * from project.pizzahut p "

# %%
cursor.execute(query)

# %%
rows = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]

# %%
import pandas as pd

# %%
df = pd.DataFrame(rows, columns=columns)

# %%
df
# Out:
#          Column1   BillID    Channel    OrderFrom            TransactionDate  \
# 0              0        0  Take Away  CALL CENTER  2021-10-01 00:00:00+00:00
# 1              1        1  Take Away        STORE  2021-10-01 00:00:00+00:00
# 2              2        2  Take Away      WEBSITE  2021-10-01 00:00:00+00:00
# 3              3        3  Take Away        STORE  2021-10-01 00:00:00+00:00
# 4              4        4   Delivery        STORE  2021-10-01 00:00:00+00:00
# ...          ...      ...        ...          ...                        ...
# 1048570  1048570  1048570   Delivery        STORE  2023-01-09 00:00:00+00:00
# 1048571  1048571  1048571  Take Away        STORE  2023-01-09 00:00:00+00:00
# 1048572  1048572  1048572  Take Away      WEBSITE  2023-01-09 00:00:00+00:00
# 1048573  1048573  1048573  Take Away        STORE  2023-01-09 00:00:00+00:00
# 1048574  1048574  1048574   Delivery  CALL CENTER  2023-01-09 00:00:00+00:00
#
# ...

# %% [markdown]
# RFM Model

# %%
df1 = df

# %%
df1
# Out:
#          Column1   BillID    Channel    OrderFrom            TransactionDate  \
# 0              0        0  Take Away  CALL CENTER  2021-10-01 00:00:00+00:00
# 1              1        1  Take Away        STORE  2021-10-01 00:00:00+00:00
# 2              2        2  Take Away      WEBSITE  2021-10-01 00:00:00+00:00
# 3              3        3  Take Away        STORE  2021-10-01 00:00:00+00:00
# 4              4        4   Delivery        STORE  2021-10-01 00:00:00+00:00
# ...          ...      ...        ...          ...                        ...
# 1048570  1048570  1048570   Delivery        STORE  2023-01-09 00:00:00+00:00
# 1048571  1048571  1048571  Take Away        STORE  2023-01-09 00:00:00+00:00
# 1048572  1048572  1048572  Take Away      WEBSITE  2023-01-09 00:00:00+00:00
# 1048573  1048573  1048573  Take Away        STORE  2023-01-09 00:00:00+00:00
# 1048574  1048574  1048574   Delivery  CALL CENTER  2023-01-09 00:00:00+00:00
#
# ...

# %%
df1 = df1[["BillID","CustomerID","TransactionDate","SalesAmount"]]

# %%
df1
# Out:
#           BillID  CustomerID            TransactionDate  SalesAmount
# 0              0     1753863  2021-10-01 00:00:00+00:00       296891
# 1              1     1124050  2021-10-01 00:00:00+00:00       301782
# 2              2     1626827  2021-10-01 00:00:00+00:00       319792
# 3              3      125643  2021-10-01 00:00:00+00:00       424762
# 4              4     2117237  2021-10-01 00:00:00+00:00       280031
# ...          ...         ...                        ...          ...
# 1048570  1048570     1398136  2023-01-09 00:00:00+00:00       178107
# 1048571  1048571     2023258  2023-01-09 00:00:00+00:00       331447
# 1048572  1048572     2041510  2023-01-09 00:00:00+00:00       381509
# 1048573  1048573     1927215  2023-01-09 00:00:00+00:00       508205
# 1048574  1048574      324317  2023-01-09 00:00:00+00:00       349016
#
# [1048575 rows x 4 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   BillID           1048575 non-null  int64
#  1   CustomerID       1048575 non-null  int64
#  2   TransactionDate  1048575 non-null  object
#  3   SalesAmount      1048575 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 32.0+ MB

# %%
df1['CustomerID'] = df1['CustomerID'].astype("str")
# Out:
# C:\Users\HP Envy\AppData\Local\Temp\ipykernel_38868\4021401883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['CustomerID'] = df1['CustomerID'].astype("str")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   BillID           1048575 non-null  int64
#  1   CustomerID       1048575 non-null  object
#  2   TransactionDate  1048575 non-null  object
#  3   SalesAmount      1048575 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 32.0+ MB

# %%
df1["TransactionDate"] = pd.to_datetime(df1["TransactionDate"])
# Out:
# C:\Users\HP Envy\AppData\Local\Temp\ipykernel_38868\3323199806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["TransactionDate"] = pd.to_datetime(df1["TransactionDate"])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   BillID           1048575 non-null  int64
#  1   CustomerID       1048575 non-null  object
#  2   TransactionDate  1048575 non-null  datetime64[ns, UTC]
#  3   SalesAmount      1048575 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(2), object(1)
# memory usage: 32.0+ MB

# %%
df1.head(10)
# Out:
#    BillID CustomerID           TransactionDate  SalesAmount
# 0       0    1753863 2021-10-01 00:00:00+00:00       296891
# 1       1    1124050 2021-10-01 00:00:00+00:00       301782
# 2       2    1626827 2021-10-01 00:00:00+00:00       319792
# 3       3     125643 2021-10-01 00:00:00+00:00       424762
# 4       4    2117237 2021-10-01 00:00:00+00:00       280031
# 5       5    1954725 2021-10-01 00:00:00+00:00       281419
# 6       6    2097093 2021-10-01 00:00:00+00:00       191624
# 7       7     602645 2021-10-01 00:00:00+00:00       201069
# 8       8    1223148 2021-10-01 00:00:00+00:00       301044
# 9       9      86157 2021-10-01 00:00:00+00:00        82851

# %%
import datetime as dt

# %%
df1['TransactionDate'] = df1['TransactionDate'].dt.strftime("%Y-%m-%d")
# Out:
# C:\Users\HP Envy\AppData\Local\Temp\ipykernel_38868\2878619264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['TransactionDate'] = df1['TransactionDate'].dt.strftime("%Y-%m-%d")

# %%
df1.head(10)
# Out:
#    BillID CustomerID TransactionDate  SalesAmount
# 0       0    1753863      2021-10-01       296891
# 1       1    1124050      2021-10-01       301782
# 2       2    1626827      2021-10-01       319792
# 3       3     125643      2021-10-01       424762
# 4       4    2117237      2021-10-01       280031
# 5       5    1954725      2021-10-01       281419
# 6       6    2097093      2021-10-01       191624
# 7       7     602645      2021-10-01       201069
# 8       8    1223148      2021-10-01       301044
# 9       9      86157      2021-10-01        82851

# %%
df1["TransactionDate"] = pd.to_datetime(df1["TransactionDate"])
# Out:
# C:\Users\HP Envy\AppData\Local\Temp\ipykernel_38868\3323199806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["TransactionDate"] = pd.to_datetime(df1["TransactionDate"])

# %%
df1_recency = df1.copy()

# %%
df1_recency
# Out:
#           BillID CustomerID TransactionDate  SalesAmount
# 0              0    1753863      2021-10-01       296891
# 1              1    1124050      2021-10-01       301782
# 2              2    1626827      2021-10-01       319792
# 3              3     125643      2021-10-01       424762
# 4              4    2117237      2021-10-01       280031
# ...          ...        ...             ...          ...
# 1048570  1048570    1398136      2023-01-09       178107
# 1048571  1048571    2023258      2023-01-09       331447
# 1048572  1048572    2041510      2023-01-09       381509
# 1048573  1048573    1927215      2023-01-09       508205
# 1048574  1048574     324317      2023-01-09       349016
#
# [1048575 rows x 4 columns]

# %%
df1_recency = df1_recency.groupby("CustomerID")["TransactionDate"].max().reset_index()

# %%
df1_recency
# Out:
#        CustomerID TransactionDate
# 0               0      2021-12-24
# 1               1      2022-03-07
# 2           10000      2023-01-07
# 3         1000000      2021-11-07
# 4         1000001      2022-06-18
# ...           ...             ...
# 583637      99998      2022-03-06
# 583638     999984      2022-01-05
# 583639     999985      2022-07-01
# 583640     999987      2021-11-01
# 583641     999993      2022-09-30
#
# [583642 rows x 2 columns]

# %%
import numpy as np

# %%
max_day = np.max(df1['TransactionDate'])

# %%
df1_recency["datediff"] = df1_recency["TransactionDate"].apply(lambda x: max_day - x)

# %%
df1_recency
# Out:
#        CustomerID TransactionDate datediff
# 0               0      2021-12-24 381 days
# 1               1      2022-03-07 308 days
# 2           10000      2023-01-07   2 days
# 3         1000000      2021-11-07 428 days
# 4         1000001      2022-06-18 205 days
# ...           ...             ...      ...
# 583637      99998      2022-03-06 309 days
# 583638     999984      2022-01-05 369 days
# 583639     999985      2022-07-01 192 days
# 583640     999987      2021-11-01 434 days
# 583641     999993      2022-09-30 101 days
#
# [583642 rows x 3 columns]

# %%
df1_recency['datediff'] = df1_recency['datediff'].dt.days

# %%
df1_recency.sort_values(by=["datediff"],ascending=True)
# Out:
#        CustomerID TransactionDate  datediff
# 389121     348823      2023-01-09         0
# 194215    1650146      2023-01-09         0
# 475965     640213      2023-01-09         0
# 396547     373503      2023-01-09         0
# 59799     1200121      2023-01-09         0
# ...           ...             ...       ...
# 288698    1969071      2021-10-01       465
# 28858     1097067      2021-10-01       465
# 540248     855250      2021-10-01       465
# 414574     433500      2021-10-01       465
# 425983      47196      2021-10-01       465
#
# [583642 rows x 3 columns]

# %%
df1_recency.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583642 entries, 0 to 583641
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   CustomerID       583642 non-null  object
#  1   TransactionDate  583642 non-null  datetime64[ns]
#  2   datediff         583642 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 13.4+ MB

# %%
q1_recency = df1_recency['datediff'].quantile(0.25)
q2_recency = df1_recency['datediff'].quantile(0.5)
q3_recency = df1_recency['datediff'].quantile(0.75)

# %%
print(q1_recency,q2_recency,q3_recency)
# Out:
# 101.0 217.0 336.0

# %%
df1_recency['R'] = df1_recency['datediff'].apply(lambda x: 4 if x < q1_recency else(3 if(x>=q1_recency) and (x<q2_recency) else(2 if(x>=q2_recency) and (x<q3_recency) else(1))))

# %%
df1
# Out:
#           BillID CustomerID TransactionDate  SalesAmount
# 0              0    1753863      2021-10-01       296891
# 1              1    1124050      2021-10-01       301782
# 2              2    1626827      2021-10-01       319792
# 3              3     125643      2021-10-01       424762
# 4              4    2117237      2021-10-01       280031
# ...          ...        ...             ...          ...
# 1048570  1048570    1398136      2023-01-09       178107
# 1048571  1048571    2023258      2023-01-09       331447
# 1048572  1048572    2041510      2023-01-09       381509
# 1048573  1048573    1927215      2023-01-09       508205
# 1048574  1048574     324317      2023-01-09       349016
#
# [1048575 rows x 4 columns]

# %%
df1_frequency = df1.groupby("CustomerID")["BillID"].count().reset_index(name="frequency")

# %%
df1_frequency
# Out:
#        CustomerID  frequency
# 0               0          1
# 1               1          1
# 2           10000          1
# 3         1000000          1
# 4         1000001          5
# ...           ...        ...
# 583637      99998          1
# 583638     999984          1
# 583639     999985          1
# 583640     999987          1
# 583641     999993          2
#
# [583642 rows x 2 columns]

# %%
q1_frequency = df1_frequency['frequency'].quantile(0.25)
q2_frequency = df1_frequency['frequency'].quantile(0.5)
q3_frequency = df1_frequency['frequency'].quantile(0.75)

# %%
print(q1_frequency,q2_frequency,q3_frequency)
# Out:
# 1.0 1.0 2.0

# %%
df1_frequency.groupby("frequency")["CustomerID"].count().reset_index(name="count")
# Out:
#     frequency   count
# 0           1  412462
# 1           2   83405
# 2           3   33954
# 3           4   17998
# 4           5   10532
# ..        ...     ...
# 85        141       1
# 86        155       1
# 87        166       1
# 88        168       1
# 89        238       1
#
# [90 rows x 2 columns]

# %%
df1_frequencyexclude1 = df1_frequency[df1_frequency["frequency"]!=1]

# %%
q1_frequency = df1_frequencyexclude1['frequency'].quantile(0.25)
q2_frequency = df1_frequencyexclude1['frequency'].quantile(0.5)
q3_frequency = df1_frequencyexclude1['frequency'].quantile(0.75)

# %%
print(q1_frequency,q2_frequency,q3_frequency)
# Out:
# 2.0 3.0 4.0

# %%
df1_frequency["F"] = df1_frequency['frequency'].apply(lambda x: 1 if x<q1_frequency else(2 if (x>=q1_frequency) and (x<q2_frequency) else(3 if (x>=q2_frequency) and (x<q3_frequency)
                                                                                                                                          else(4))))

# %%
df1_frequency
# Out:
#        CustomerID  frequency  F
# 0               0          1  1
# 1               1          1  1
# 2           10000          1  1
# 3         1000000          1  1
# 4         1000001          5  4
# ...           ...        ... ..
# 583637      99998          1  1
# 583638     999984          1  1
# 583639     999985          1  1
# 583640     999987          1  1
# 583641     999993          2  2
#
# [583642 rows x 3 columns]

# %%
df1_frequency.groupby("F")['CustomerID'].count().reset_index()
# Out:
#    F  CustomerID
# 0  1      412462
# 1  2       83405
# 2  3       33954
# 3  4       53821

# %%
df1
# Out:
#           BillID CustomerID TransactionDate  SalesAmount
# 0              0    1753863      2021-10-01       296891
# 1              1    1124050      2021-10-01       301782
# 2              2    1626827      2021-10-01       319792
# 3              3     125643      2021-10-01       424762
# 4              4    2117237      2021-10-01       280031
# ...          ...        ...             ...          ...
# 1048570  1048570    1398136      2023-01-09       178107
# 1048571  1048571    2023258      2023-01-09       331447
# 1048572  1048572    2041510      2023-01-09       381509
# 1048573  1048573    1927215      2023-01-09       508205
# 1048574  1048574     324317      2023-01-09       349016
#
# [1048575 rows x 4 columns]

# %%
df1_monetary = df1.groupby("CustomerID")["SalesAmount"].sum().reset_index()

# %%
df1_monetary
# Out:
#        CustomerID  SalesAmount
# 0               0       411663
# 1               1       105503
# 2           10000       145127
# 3         1000000       190147
# 4         1000001      2416216
# ...           ...          ...
# 583637      99998       159653
# 583638     999984       176064
# 583639     999985       415034
# 583640     999987       168534
# 583641     999993       368945
#
# [583642 rows x 2 columns]

# %%
q1_monetary = df1_monetary["SalesAmount"].quantile(0.25)
q2_monetary = df1_monetary["SalesAmount"].quantile(0.5)
q3_monetary = df1_monetary["SalesAmount"].quantile(0.75)

# %%
print(q1_monetary,q2_monetary,q3_monetary)
# Out:
# 201289.0 311816.0 567481.25

# %%
df1_monetary["M"] = df1_monetary["SalesAmount"].apply(lambda x: 1 if x<q1_monetary else(2 if (x>=q1_monetary) and (x<q2_monetary) else(3 if (x >=q2_monetary) and (x<q3_monetary) else(4))))

# %%
df1_monetary
# Out:
#        CustomerID  SalesAmount  M
# 0               0       411663  3
# 1               1       105503  1
# 2           10000       145127  1
# 3         1000000       190147  1
# 4         1000001      2416216  4
# ...           ...          ... ..
# 583637      99998       159653  1
# 583638     999984       176064  1
# 583639     999985       415034  3
# 583640     999987       168534  1
# 583641     999993       368945  3
#
# [583642 rows x 3 columns]

# %%
df1_monetary.groupby("M")["CustomerID"].count().reset_index()
# Out:
#    M  CustomerID
# 0  1      145910
# 1  2      145910
# 2  3      145911
# 3  4      145911

# %%
df1_recency
# Out:
#        CustomerID TransactionDate  datediff  R
# 0               0      2021-12-24       381  1
# 1               1      2022-03-07       308  2
# 2           10000      2023-01-07         2  4
# 3         1000000      2021-11-07       428  1
# 4         1000001      2022-06-18       205  3
# ...           ...             ...       ... ..
# 583637      99998      2022-03-06       309  2
# 583638     999984      2022-01-05       369  1
# 583639     999985      2022-07-01       192  3
# 583640     999987      2021-11-01       434  1
# 583641     999993      2022-09-30       101  3
#
# [583642 rows x 4 columns]

# %%
df1_frequency
# Out:
#        CustomerID  frequency  F
# 0               0          1  1
# 1               1          1  1
# 2           10000          1  1
# 3         1000000          1  1
# 4         1000001          5  4
# ...           ...        ... ..
# 583637      99998          1  1
# 583638     999984          1  1
# 583639     999985          1  1
# 583640     999987          1  1
# 583641     999993          2  2
#
# [583642 rows x 3 columns]

# %%
df1_monetary
# Out:
#        CustomerID  SalesAmount  M
# 0               0       411663  3
# 1               1       105503  1
# 2           10000       145127  1
# 3         1000000       190147  1
# 4         1000001      2416216  4
# ...           ...          ... ..
# 583637      99998       159653  1
# 583638     999984       176064  1
# 583639     999985       415034  3
# 583640     999987       168534  1
# 583641     999993       368945  3
#
# [583642 rows x 3 columns]

# %%
df_rfm = pd.merge(pd.merge(df1_recency,df1_frequency,on="CustomerID"),df1_monetary,on="CustomerID")

# %%
df_rfm
# Out:
#        CustomerID TransactionDate  datediff  R  frequency  F  SalesAmount  M
# 0               0      2021-12-24       381  1          1  1       411663  3
# 1               1      2022-03-07       308  2          1  1       105503  1
# 2           10000      2023-01-07         2  4          1  1       145127  1
# 3         1000000      2021-11-07       428  1          1  1       190147  1
# 4         1000001      2022-06-18       205  3          5  4      2416216  4
# ...           ...             ...       ... ..        ... ..          ... ..
# 583637      99998      2022-03-06       309  2          1  1       159653  1
# 583638     999984      2022-01-05       369  1          1  1       176064  1
# 583639     999985      2022-07-01       192  3          1  1       415034  3
# 583640     999987      2021-11-01       434  1          1  1       168534  1
# 583641     999993      2022-09-30       101  3          2  2       368945  3
#
# [583642 rows x 8 columns]

# %%
df_rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583642 entries, 0 to 583641
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   CustomerID       583642 non-null  object
#  1   TransactionDate  583642 non-null  datetime64[ns]
#  2   datediff         583642 non-null  int64
#  3   R                583642 non-null  int64
#  4   frequency        583642 non-null  int64
#  5   F                583642 non-null  int64
#  6   SalesAmount      583642 non-null  int64
#  7   M                583642 non-null  int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 40.1+ MB

# %%
RFM = ["R","F","M"]
for i in RFM:
    df_rfm[i] = df_rfm[i].astype("str")

# %%
df_rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583642 entries, 0 to 583641
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   CustomerID       583642 non-null  object
#  1   TransactionDate  583642 non-null  datetime64[ns]
#  2   datediff         583642 non-null  int64
#  3   R                583642 non-null  object
#  4   frequency        583642 non-null  int64
#  5   F                583642 non-null  object
#  6   SalesAmount      583642 non-null  int64
#  7   M                583642 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 40.1+ MB

# %%
df_rfm["RFM"] = df_rfm["R"] + df_rfm["F"] + df_rfm["M"]

# %%
df_rfm
# Out:
#        CustomerID TransactionDate  datediff  R  frequency  F  SalesAmount  M  \
# 0               0      2021-12-24       381  1          1  1       411663  3
# 1               1      2022-03-07       308  2          1  1       105503  1
# 2           10000      2023-01-07         2  4          1  1       145127  1
# 3         1000000      2021-11-07       428  1          1  1       190147  1
# 4         1000001      2022-06-18       205  3          5  4      2416216  4
# ...           ...             ...       ... ..        ... ..          ... ..
# 583637      99998      2022-03-06       309  2          1  1       159653  1
# 583638     999984      2022-01-05       369  1          1  1       176064  1
# 583639     999985      2022-07-01       192  3          1  1       415034  3
# 583640     999987      2021-11-01       434  1          1  1       168534  1
# 583641     999993      2022-09-30       101  3          2  2       368945  3
#
#         RFM
# 0       113
# 1       211
# ...

# %%
df_rfm.groupby("RFM")["CustomerID"].count().reset_index(name="count").sort_values(by="count",ascending=False)
# Out:
#     RFM  count
# 1   112  46780
# 0   111  43642
# 16  211  39335
# 17  212  38682
# 2   113  34685
# ..  ...    ...
# 28  241     32
# 60  441     24
# 44  341     23
# 13  142     20
# 12  141      8
#
# [64 rows x 2 columns]

# %%
df_rfm.to_csv("outputrfm.csv")

# %%
df_rfm
# Out:
#        CustomerID TransactionDate  datediff  R  frequency  F  SalesAmount  M  \
# 0               0      2021-12-24       381  1          1  1       411663  3
# 1               1      2022-03-07       308  2          1  1       105503  1
# 2           10000      2023-01-07         2  4          1  1       145127  1
# 3         1000000      2021-11-07       428  1          1  1       190147  1
# 4         1000001      2022-06-18       205  3          5  4      2416216  4
# ...           ...             ...       ... ..        ... ..          ... ..
# 583637      99998      2022-03-06       309  2          1  1       159653  1
# 583638     999984      2022-01-05       369  1          1  1       176064  1
# 583639     999985      2022-07-01       192  3          1  1       415034  3
# 583640     999987      2021-11-01       434  1          1  1       168534  1
# 583641     999993      2022-09-30       101  3          2  2       368945  3
#
#         RFM
# 0       113
# 1       211
# ...

# %%
print("recency: ",q1_recency,q2_recency,q3_recency)
print("frequency: ",q1_frequency, q2_frequency, q3_frequency)
print("monetary: ",q1_monetary, q2_monetary,q3_monetary)
# Out:
# recency:  101.0 217.0 336.0
# frequency:  2.0 3.0 4.0
# monetary:  201289.0 311816.0 567481.25

# %%
a = ['111', '112', '211', '212', '113', '213', '114','222', '122', '221', '121', '242', '131', '241', '142', '141','311', '312', '411', '412', '422', '322', '421', '321', '313', '413', '324', '424', '323', '423', '314', '414',
     '444', '344', '434', '334', '443', '343','433','333',
     '342', '442', '431', '441', '341','234', '244', '134', '233', '144', '133', '143','224', '223', '123', '124']

# %%
b= df_rfm['RFM'].unique()
b
# Out:
# array(['113', '211', '411', '111', '344', '413', '433', '112', '313',
#        '234', '212', '412', '114', '312', '311', '122', '423', '223',
#        '134', '434', '244', '323', '444', '123', '322', '124', '334',
#        '214', '324', '224', '314', '424', '213', '221', '222', '443',
#        '422', '414', '233', '242', '144', '121', '333', '421', '321',
#        '243', '131', '432', '241', '343', '143', '133', '331', '441',
#        '141', '342', '431', '332', '232', '132', '442', '231', '341',
#        '142'], dtype=object)

# %%
set(b)- set(a)
# Out:
# {'132', '214', '231', '232', '243', '331', '332', '432'}

# %%
len(a)
# Out:
# 56

# %%
len(b)
# Out:
# 64

# %%
elements_in_b_not_in_a = [element for element in b if element not in a]
print("Elements in list b but not in list a:", elements_in_b_not_in_a)
len(elements_in_b_not_in_a)
# Out:
# Elements in list b but not in list a: ['113', '211', '411', '111', '344', '413', '433', '112', '313', '234', '212', '412', '114', '312', '311', '122', '423', '223', '134', '434', '244', '323', '444', '123', '322', '124', '334', '214', '324', '224', '314', '424', '213', '221', '222', '443', '422', '414', '233', '242', '144', '121', '333', '421', '321', '243', '131', '432', '241', '343', '143', '133', '331', '441', '141', '342', '431', '332', '232', '132', '442', '231', '341', '142']
# 64

# %%
b= df_rfm['RFM'].unique()

# %%
b
# Out:
# 64

# %%
set_a = set(a)
set_b = set(b)

# %%
set_b - set_a
# Out:
# {'111',
#  '112',
#  '113',
#  '114',
#  '121',
#  '122',
#  '123',
#  '124',
#  '131',
#  '132',
#  '133',
#  '134',
#  '141',
#  '142',
#  '143',
#  '144',
#  '211',
#  '212',
#  '213',
#  '214',
#  '221',
#  '222',
#  '223',
#  '224',
#  '231',
#  '232',
#  '233',
#  '234',
#  '241',
#  '242',
#  '243',
#  '244',
#  '311',
#  '312',
#  '313',
#  '314',
#  '321',
#  '322',
#  '323',
#  '324',
#  '331',
#  '332',
#  '333',
#  '334',
#  '341',
#  '342',
#  '343',
#  '344',
#  '411',
#  '412',
#  '413',
#  '414',
#  '421',
#  '422',
#  '423',
#  '424',
#  '431',
#  '432',
#  '433',
#  '434',
#  '441',
#  '442',
#  '443',
#  '444'}

# %%
for i in set_a:
    if i not in set_b:
        print(i)
# Out:
# 131
# 133
# 134
# 141
# 142
# 143
# 144
# 411
# 412
# 413
# 414
# 421
# 422
# 423
# 424
# 431
# 433
# 434
# 311
# 312
# 313
# 314
# 443
# 444
# 442
# 441
# 321
# 322
# 323
# 324
# 333
# 334
# 211
# 212
# 213
# 342
# 343
# 344
# 341
# 221
# 222
# 223
# 224
# 233
# 234
# 111
# 112
# 113
# 114
# 242
# 241
# 244
# 121
# 122
# 123
# 124

# %%
my_series = pd.Series(a)

# %%
duplicates = my_series[my_series.duplicated()]

# %%
print(duplicates)
# Out:
# Series([], dtype: int64)

# %%
df
# Out:
#          Column1   BillID    Channel    OrderFrom            TransactionDate  \
# 0              0        0  Take Away  CALL CENTER  2021-10-01 00:00:00+00:00
# 1              1        1  Take Away        STORE  2021-10-01 00:00:00+00:00
# 2              2        2  Take Away      WEBSITE  2021-10-01 00:00:00+00:00
# 3              3        3  Take Away        STORE  2021-10-01 00:00:00+00:00
# 4              4        4   Delivery        STORE  2021-10-01 00:00:00+00:00
# ...          ...      ...        ...          ...                        ...
# 1048570  1048570  1048570   Delivery        STORE  2023-01-09 00:00:00+00:00
# 1048571  1048571  1048571  Take Away        STORE  2023-01-09 00:00:00+00:00
# 1048572  1048572  1048572  Take Away      WEBSITE  2023-01-09 00:00:00+00:00
# 1048573  1048573  1048573  Take Away        STORE  2023-01-09 00:00:00+00:00
# 1048574  1048574  1048574   Delivery  CALL CENTER  2023-01-09 00:00:00+00:00
#
# ...

# %%
np.min(df['TransactionDate'])
# Out:
# '2021-10-01 00:00:00+00:00'

# %%
np.max(df['TransactionDate'])
# Out:
# '2023-01-09 00:00:00+00:00'
